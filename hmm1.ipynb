# %%
Cython --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Cython --version
#
# NameError: name 'Cython' is not defined

# %%
import pomegranate

# %%
from pomegranate import State, DiscreteDistribution

# Define the distributions for emissions
emission_probs = [[0.2, 0.5, 0.3],  # Emission probabilities for State 1
                  [0.4, 0.4, 0.2]]  # Emission probabilities for State 2

# Define the Hidden Markov Model
model = HiddenMarkovModel()

# Define the states with their emission distributions
s1 = State(DiscreteDistribution({'obs1': emission_probs[0][0],
                                 'obs2': emission_probs[0][1],
                                 'obs3': emission_probs[0][2]}), name='State1')
s2 = State(DiscreteDistribution({'obs1': emission_probs[1][0],
                                 'obs2': emission_probs[1][1],
                                 'obs3': emission_probs[1][2]}), name='State2')

# Add states to the model
model.add_states(s1, s2)

# Set initial state probabilities
model.add_transition(model.start, s1, 0.6)
model.add_transition(model.start, s2, 0.4)

# Set transition probabilities between states
model.add_transition(s1, s1, 0.7)
model.add_transition(s1, s2, 0.3)
model.add_transition(s2, s1, 0.4)
model.add_transition(s2, s2, 0.6)

# Bake the model
model.bake()

# Visualize the state diagram
model.plot()

# Compute the probability of a given output sequence
output_sequence = ['obs1', 'obs2', 'obs3']
probability = model.log_probability(output_sequence)
print("Log Probability of Output Sequence:", probability)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from pomegranate import State, DiscreteDistribution
#       3 # Define the distributions for emissions
#       4 emission_probs = [[0.2, 0.5, 0.3],  # Emission probabilities for State 1
#       5                   [0.4, 0.4, 0.2]]  # Emission probabilities for State 2
#
# ImportError: cannot import name 'State' from 'pomegranate' (C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pomegranate\__init__.py)

# %%
import pomegranate

# Define the states
sunny = State(DiscreteDistribution({'yes': 0.8, 'no': 0.2}), name='Sunny')
rainy = State(DiscreteDistribution({'yes': 0.4, 'no': 0.6}), name='Rainy')

# Create the Hidden Markov Model
model = HiddenMarkovModel()

# Add the states to the model
model.add_states(sunny, rainy)

# Add transitions between states
model.add_transition(model.start, sunny, 0.5)
model.add_transition(model.start, rainy, 0.5)
model.add_transition(sunny, sunny, 0.7)
model.add_transition(sunny, rainy, 0.3)
model.add_transition(rainy, sunny, 0.4)
model.add_transition(rainy, rainy, 0.6)

# Finalize the model
model.bake()

# Visualize the state diagram
model.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pomegranate
#       3 # Define the states
# ----> 4 sunny = State(DiscreteDistribution({'yes': 0.8, 'no': 0.2}), name='Sunny')
#       5 rainy = State(DiscreteDistribution({'yes': 0.4, 'no': 0.6}), name='Rainy')
#       7 # Create the Hidden Markov Model
#
# NameError: name 'State' is not defined

# %%
from pomegranate import HiddenMarkovModel, State, DiscreteDistribution


# Define the distributions for emissions
emission_probs = [[0.2, 0.5, 0.3],  # Emission probabilities for State 1
                  [0.4, 0.4, 0.2]]  # Emission probabilities for State 2

# Define the Hidden Markov Model
model = HiddenMarkovModel()

# Define the states with their emission distributions
s1 = State(DiscreteDistribution({'obs1': emission_probs[0][0],
                                 'obs2': emission_probs[0][1],
                                 'obs3': emission_probs[0][2]}), name='State1')
s2 = State(DiscreteDistribution({'obs1': emission_probs[1][0],
                                 'obs2': emission_probs[1][1],
                                 'obs3': emission_probs[1][2]}), name='State2')

# Add states to the model
model.add_states(s1, s2)

# Set initial state probabilities
model.add_transition(model.start, s1, 1.0)  # Always start at State 1 by default
model.add_transition(model.start, s2, 0.0)  # No transition to State 2 initially

# Set transition probabilities between states
model.add_transition(s1, s1, 0.7)
model.add_transition(s1, s2, 0.3)
model.add_transition(s2, s1, 0.4)
model.add_transition(s2, s2, 0.6)

# Bake the model
model.bake()

# Visualize the state diagram
model.plot()

# Compute the probability of a given output sequence
output_sequence = ['obs1', 'obs2', 'obs.3']
probability = model.log_probability(output_sequence)
print("Log Probability of Output Sequence:", probability)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pomegranate import HiddenMarkovModel, State, DiscreteDistribution
#       4 # Define the distributions for emissions
#       5 emission_probs = [[0.2, 0.5, 0.3],  # Emission probabilities for State 1
#       6                   [0.4, 0.4, 0.2]]  # Emission probabilities for State 2
#
# ImportError: cannot import name 'HiddenMarkovModel' from 'pomegranate' (C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pomegranate\__init__.py)

# %%
from pomegranate import State, DiscreteDistribution, MarkovChain

# Define the emission probabilities
emission_probs = [{'obs1': 0.2, 'obs2': 0.5, 'obs3': 0.3},  # Emission probabilities for State 1
                  {'obs1': 0.4, 'obs2': 0.4, 'obs3': 0.2}]  # Emission probabilities for State 2

# Define the states with their emission distributions
s1 = State(DiscreteDistribution(emission_probs[0]), name='State1')
s2 = State(DiscreteDistribution(emission_probs[1]), name='State2')

# Define transitions between states
transitions = {
    s1: {s1: 0.7, s2: 0.3},
    s2: {s1: 0.4, s2: 0.6}
}

# Create the Markov Chain
model = MarkovChain.from_matrix(transitions)

# Set initial state probabilities
model.start = [1, 0]  # Always start at State 1 by default

# Visualize the state diagram
model.plot()

# Compute the probability of a given output sequence
output_sequence = ['obs1', 'obs2', 'obs3']
probability = model.probability(output_sequence)
print("Probability of Output Sequence:", probability)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pomegranate import State, DiscreteDistribution, MarkovChain
#       3 # Define the emission probabilities
#       4 emission_probs = [{'obs1': 0.2, 'obs2': 0.5, 'obs3': 0.3},  # Emission probabilities for State 1
#       5                   {'obs1': 0.4, 'obs2': 0.4, 'obs3': 0.2}]  # Emission probabilities for State 2
#
# ImportError: cannot import name 'State' from 'pomegranate' (C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pomegranate\__init__.py)

# %%
# !pip install pomegranate
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib inline

# %%
from pomegranate import State, DiscreteDistribution, MarkovChain

# Define the emission probabilities
emission_probs = [{'obs1': 0.2, 'obs2': 0.5, 'obs3': 0.3},  # Emission probabilities for State 1
                  {'obs1': 0.4, 'obs2': 0.4, 'obs3': 0.2}]  # Emission probabilities for State 2

# Define the states with their emission distributions
s1 = State(DiscreteDistribution(emission_probs[0]), name='State1')
s2 = State(DiscreteDistribution(emission_probs[1]), name='State2')

# Define transitions between states
transitions = {
    s1: {s1: 0.7, s2: 0.3},
    s2: {s1: 0.4, s2: 0.6}
}

# Create the Markov Chain
model = MarkovChain.from_matrix(transitions)

# Set initial state probabilities
model.start = [1, 0]  # Always start at State 1 by default

# Visualize the state diagram
model.plot()

# Compute the probability of a given output sequence
output_sequence = ['obs1', 'obs2', 'obs3']
probability = model.probability(output_sequence)
print("Probability of Output Sequence:", probability)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from pomegranate import State, DiscreteDistribution, MarkovChain
#       3 # Define the emission probabilities
#       4 emission_probs = [{'obs1': 0.2, 'obs2': 0.5, 'obs3': 0.3},  # Emission probabilities for State 1
#       5                   {'obs1': 0.4, 'obs2': 0.4, 'obs3': 0.2}]  # Emission probabilities for State 2
#
# ImportError: cannot import name 'State' from 'pomegranate' (C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pomegranate\__init__.py)

# %%
 pip install Cython
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting Cython
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB 1.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.1/2.8 MB 1.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.2/2.8 MB 1.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.8 MB 1.6 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/2.8 MB 1.9 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/2.8 MB 2.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.7/2.8 MB 2.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.9/2.8 MB 2.4 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.8 MB 2.3 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.8 MB 2.4 MB/s eta 0:00:01
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 186.2 kB/s eta 0:00:12
#     --------------------------------------- 0.0/2.1 MB 186.2 kB/s eta 0:00:12
#     --------------------------------------- 0.0/2.1 MB 186.2 kB/s eta 0:00:12
#     --------------------------------------- 0.0/2.1 MB 115.5 kB/s eta 0:00:18
#    - -------------------------------------- 0.1/2.1 MB 163.6 kB/s eta 0:00:13
#    - -------------------------------------- 0.1/2.1 MB 170.7 kB/s eta 0:00:12
#    - -------------------------------------- 0.1/2.1 MB 209.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/2.1 MB 218.3 kB/s eta 0:00:10
# ...

# %%
pip install pomegranate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define transition probabilities
transitions = {
    'State 1': {'State 1': 0.7, 'State 2': 0.3},
    'State 2': {'State 1': 0.4, 'State 2': 0.6}
}

# Create directed graph
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(transitions)

# Add edges with probabilities as labels
for source, targets in transitions.items():
    for target, probability in targets.items():
        G.add_edge(source, target, label=probability)

# Draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1500, node_color="skyblue", font_size=12, font_weight="bold", arrows=True)
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show plot
plt.title("State Diagram of Probabilities")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from hmmlearn import hmm

# Generate sample data
np.random.seed(42)
data = np.concatenate([np.random.normal(loc=0, scale=1, size=(100, 2)),
                       np.random.normal(loc=3, scale=1, size=(100, 2))])

# Train HMM
model = hmm.GaussianHMM(n_components=2)
model.fit(data)

# Get transition matrix
transition_matrix = model.transmat_

# Define states
states = [f"State {i+1}" for i in range(model.n_components)]

# Create directed graph
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(states)

# Add edges with probabilities as labels
for i, source in enumerate(states):
    for j, target in enumerate(states):
        G.add_edge(source, target, label=transition_matrix[i, j])

# Draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1500, node_color="skyblue", font_size=12, font_weight="bold", arrows=True)
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show plot
plt.title("State Diagram for HMM")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from hmmlearn import hmm

# Define the number of states and emission observations
n_states = 3  # Change the number of states as needed
n_observations = 2  # Change the number of emission observations as needed

# Generate sample data or provide your own data
# Replace this part with your actual data
np.random.seed(42)
data = np.concatenate([np.random.normal(loc=0, scale=1, size=(100, n_observations)),
                       np.random.normal(loc=3, scale=1, size=(100, n_observations))])

# Train HMM
model = hmm.GaussianHMM(n_components=n_states)  # Change the number of components
model.fit(data)

# Get transition matrix and emission probabilities
transition_matrix = model.transmat_
emission_probs = model.means_  # Means of Gaussian distributions for each state

# Define states with appropriate labels
states = [f"State {i+1}" for i in range(n_states)]  # Change state labels as needed

# Create directed graph
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(states)

# Add edges with probabilities as labels
for i, source in enumerate(states):
    for j, target in enumerate(states):
        transition_prob = transition_matrix[i, j]
        G.add_edge(source, target, label=f"{transition_prob:.2f}")  # Format probability to two decimal places

# Draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1500, node_color="skyblue", font_size=12, font_weight="bold", arrows=True)
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show plot
plt.title("State Diagram for HMM")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# Define transition probabilities between states
transition_matrix = np.array([[0.7, 0.3],  # Transition probabilities from 'Coffee preferred' state
                              [0.5, 0.5]])  # Transition probabilities from 'Iced Tea preferred' state

# Define emission observation probabilities
emission_probs = {'Coffee preferred': {'Coffee': 0.6, 'Iced Tea': 0.1, 'Lemonade': 0.3},
                  'Iced Tea preferred': {'Coffee': 0.1, 'Iced Tea': 0.7, 'Lemonade': 0.2}}

# Define states and emission observations
states = ['Coffee preferred', 'Iced Tea preferred']
observations = ['Coffee', 'Iced Tea', 'Lemonade']

# Create directed graph
G = nx.DiGraph()
G.add_nodes_from(states)

# Add edges with transition probabilities as labels
for i, source in enumerate(states):
    for j, target in enumerate(states):
        transition_prob = transition_matrix[i, j]
        G.add_edge(source, target, label=f"{transition_prob:.2f}")  # Format probability to two decimal places

# Draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1500, node_color="skyblue", font_size=12, font_weight="bold", arrows=True)

# Add node labels
nx.draw_networkx_labels(G, pos, font_color='black', font_size=12, font_weight='bold')

# Add edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

# Show plot
plt.title("State Diagram for HMM")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# Define transition probabilities between states
transition_matrix = np.array([[0.7, 0.3],  # Transition probabilities from 'Coffee preferred' state
                              [0.5, 0.5]])  # Transition probabilities from 'Iced Tea preferred' state

# Define emission observation probabilities
emission_probs = {'Coffee preferred': {'Coffee': 0.6, 'Iced Tea': 0.1, 'Lemonade': 0.3},
                  'Iced Tea preferred': {'Coffee': 0.1, 'Iced Tea': 0.7, 'Lemonade': 0.2}}

# Define states and emission observations
states = ['Coffee preferred', 'Iced Tea preferred']
observations = ['Coffee', 'Iced Tea', 'Lemonade']

# Define output sequence
output_sequence = ['Coffee', 'Iced Tea', 'Lemonade']

# Calculate initial probability distribution
initial_prob = np.array([0.5, 0.5])  # Assuming equal probability for each initial state

# Initialize forward probabilities
forward_prob = np.zeros((len(output_sequence), len(states)))

# Initialize scaling factors
scaling_factors = np.zeros(len(output_sequence))

# Initialize forward probabilities for the first observation
for i, state in enumerate(states):
    forward_prob[0, i] = initial_prob[i] * emission_probs[state][output_sequence[0]]

# Iterate over the remaining observations
for t in range(1, len(output_sequence)):
    for j, state in enumerate(states):
        forward_prob[t, j] = np.sum(forward_prob[t - 1, i] * transition_matrix[i, j] * emission_probs[state][output_sequence[t]] for i in range(len(states)))
    
    # Normalize forward probabilities and calculate scaling factors
    scaling_factors[t] = np.sum(forward_prob[t])
    forward_prob[t] /= scaling_factors[t]

# Calculate the probability of the output sequence
probability = np.prod(scaling_factors)

# Print the probability
print("Probability of output sequence:", probability)

# Create directed graph
G = nx.DiGraph()
G.add_nodes_from(states)

# Add edges with transition probabilities as labels
for i, source in enumerate(states):
    for j, target in enumerate(states):
        transition_prob = transition_matrix[i, j]
        G.add_edge(source, target, label=f"{transition_prob:.2f}")  # Format probability to two decimal places

# Draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1500, node_color="skyblue", font_size=12, font_weight="bold", arrows=True)

# Add node labels
nx.draw_networkx_labels(G, pos, font_color='black', font_size=12, font_weight='bold')

# Add edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

# Show plot
plt.title("State Diagram for HMM")
plt.show()
# Out:
# Probability of output sequence: 0.0
# C:\Users\admin\AppData\Local\Temp\ipykernel_13644\1499586998.py:36: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   forward_prob[t, j] = np.sum(forward_prob[t - 1, i] * transition_matrix[i, j] * emission_probs[state][output_sequence[t]] for i in range(len(states)))

# %%
import networkx as nx
import matplotlib.pyplot as plt
from pomegranate import State

# Define states
rainy = State(DiscreteDistribution({'rainy': 1.0}), name='Rainy')
cloudy = State(DiscreteDistribution({'cloudy': 1.0}), name='Cloudy')
sunny = State(DiscreteDistribution({'sunny': 1.0}), name='Sunny')

# Define transition matrix
transition_matrix = np.array([[0.7, 0.2, 0.1],   # Transition probabilities from rainy
                              [0.3, 0.5, 0.2],   # Transition probabilities from cloudy
                              [0.1, 0.3, 0.6]])  # Transition probabilities from sunny

# Add transitions
model = HiddenMarkovModel()
model.add_states(rainy, cloudy, sunny)
model.add_transition(model.start, rainy, 1.0)  # Always start with rainy
model.add_transition(rainy, rainy, transition_matrix[0, 0])
model.add_transition(rainy, cloudy, transition_matrix[0, 1])
model.add_transition(rainy, sunny, transition_matrix[0, 2])
model.add_transition(cloudy, rainy, transition_matrix[1, 0])
model.add_transition(cloudy, cloudy, transition_matrix[1, 1])
model.add_transition(cloudy, sunny, transition_matrix[1, 2])
model.add_transition(sunny, rainy, transition_matrix[2, 0])
model.add_transition(sunny, cloudy, transition_matrix[2, 1])
model.add_transition(sunny, sunny, transition_matrix[2, 2])
model.add_transition(rainy, model.end, 0.1)  # End with 0.1 probability from rainy
model.add_transition(cloudy, model.end, 0.1)  # End with 0.1 probability from cloudy
model.add_transition(sunny, model.end, 0.1)  # End with 0.1 probability from sunny

model.bake()

# Create a directed graph
G = nx.DiGraph()

# Add nodes
for state in model.states:
    G.add_node(state.name)

# Add edges
for state in model.states:
    for next_state, prob in state.edges:
        G.add_edge(state.name, next_state.name, weight=prob)

# Draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1500, node_color="skyblue", font_size=12, font_weight="bold", arrows=True)

# Show plot
plt.title("State Diagram for HMM")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 import networkx as nx
#       2 import matplotlib.pyplot as plt
# ----> 3 from pomegranate import State
#       5 # Define states
#       6 rainy = State(DiscreteDistribution({'rainy': 1.0}), name='Rainy')
#
# ImportError: cannot import name 'State' from 'pomegranate' (C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pomegranate\__init__.py)

# %%
import networkx as nx
import matplotlib.pyplot as plt
from pomegranate import DiscreteDistribution, HiddenMarkovModel

# Define transition matrix
transition_matrix = [[0.7, 0.2, 0.1],   # Transition probabilities from rainy
                     [0.3, 0.5, 0.2],   # Transition probabilities from cloudy
                     [0.1, 0.3, 0.6]]   # Transition probabilities from sunny

# Define emission observation probabilities
emission_probs = [{'rainy': 1.0}, {'cloudy': 1.0}, {'sunny': 1.0}]

# Create Hidden Markov Model
model = HiddenMarkovModel()

# Add states and transitions
for i, emission_prob in enumerate(emission_probs):
    distribution = DiscreteDistribution(emission_prob)
    state = HiddenMarkovModel(distribution)
    model.add_state(state)
    for j, prob in enumerate(transition_matrix[i]):
        model.add_transition(model.start if i == 0 else model.states[i - 1], state, prob)

# Bake the model
model.bake()

# Create a directed graph
G = nx.DiGraph()

# Add nodes
for state in model.states:
    G.add_node(state.name)

# Add edges
for state in model.states:
    for next_state in state.edges:
        G.add_edge(state.name, next_state[0].name, weight=state.edges[next_state])

# Draw graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1500, node_color="skyblue", font_size=12, font_weight="bold", arrows=True)

# Show plot
plt.title("State Diagram for HMM")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 3
#       1 import networkx as nx
#       2 import matplotlib.pyplot as plt
# ----> 3 from pomegranate import DiscreteDistribution, HiddenMarkovModel
#       5 # Define transition matrix
#       6 transition_matrix = [[0.7, 0.2, 0.1],   # Transition probabilities from rainy
#       7                      [0.3, 0.5, 0.2],   # Transition probabilities from cloudy
#       8                      [0.1, 0.3, 0.6]]   # Transition probabilities from sunny
#
# ImportError: cannot import name 'DiscreteDistribution' from 'pomegranate' (C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pomegranate\__init__.py)
